# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("googleplaystore.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.duplicated().sum()
# Out:
# 483

# %%
df.drop_duplicates(inplace = True)

# %%
df.Reviews=pd.to_numeric(df.Reviews,errors = "coerce")

# %%
df.Size.unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
#        '5.1M', '61M', '66M', '79k', '8.4M', '118k', '44M', '695k', '1.6M',
#        '6.2M', '18k', '53M', '1.4M', '3.0M', '5.8M', '3.8M', '9.6M',
#        '45M', '63M', '49M', '77M', '4.4M', '4.8M', '70M', '6.9M', '9.3M',
#        '10.0M', '8.1M', '36M', '84M', '97M', '2.0M', '1.9M', '1.8M',
#        '5.3M', '47M', '556k', '526k', '76M', '7.6M', '59M', '9.7M', '78M',
#        '72M', '43M', '7.7M', '6.3M', '334k', '34M', '93M', '65M', '79M',
#        '100M', '58M', '50M', '68M', '64M', '67M', '60M', '94M', '232k',
#        '99M', '624k', '95M', '8.5k', '41k', '292k', '11k', '80M', '1.7M',
#        '74M', '62M', '69M', '75M', '98M', '85M', '82M', '96M', '87M',
#        '71M', '86M', '91M', '81M', '92M', '83M', '88M', '704k', '862k',
#        '899k', '378k', '266k', '375k', '1.3M', '975k', '980k', '4.1M',
#        '89M', '696k', '544k', '525k', '920k', '779k', '853k', '720k',
#        '713k', '772k', '318k', '58k', '241k', '196k', '857k', '51k',
#        '953k', '865k', '251k', '930k', '540k', '313k', '746k', '203k',
#        '26k', '314k', '239k', '371k', '220k', '730k', '756k', '91k',
#        '293k', '17k', '74k', '14k', '317k', '78k', '924k', '902k', '818k',
#        '81k', '939k', '169k', '45k', '475k', '965k', '90M', '545k', '61k',
#        '283k', '655k', '714k', '93k', '872k', '121k', '322k', '1.0M',
#        '976k', '172k', '238k', '549k', '206k', '954k', '444k', '717k',
#        '210k', '609k', '308k', '705k', '306k', '904k', '473k', '175k',
#        '350k', '383k', '454k', '421k', '70k', '812k', '442k', '842k',
#        '417k', '412k', '459k', '478k', '335k', '782k', '721k', '430k',
#        '429k', '192k', '200k', '460k', '728k', '496k', '816k', '414k',
#        '506k', '887k', '613k', '243k', '569k', '778k', '683k', '592k',
#        '319k', '186k', '840k', '647k', '191k', '373k', '437k', '598k',
#        '716k', '585k', '982k', '222k', '219k', '55k', '948k', '323k',
#        '691k', '511k', '951k', '963k', '25k', '554k', '351k', '27k',
#        '82k', '208k', '913k', '514k', '551k', '29k', '103k', '898k',
#        '743k', '116k', '153k', '209k', '353k', '499k', '173k', '597k',
#        '809k', '122k', '411k', '400k', '801k', '787k', '237k', '50k',
#        '643k', '986k', '97k', '516k', '837k', '780k', '961k', '269k',
#        '20k', '498k', '600k', '749k', '642k', '881k', '72k', '656k',
#        '601k', '221k', '228k', '108k', '940k', '176k', '33k', '663k',
#        '34k', '942k', '259k', '164k', '458k', '245k', '629k', '28k',
#        '288k', '775k', '785k', '636k', '916k', '994k', '309k', '485k',
#        '914k', '903k', '608k', '500k', '54k', '562k', '847k', '957k',
#        '688k', '811k', '270k', '48k', '329k', '523k', '921k', '874k',
#        '981k', '784k', '280k', '24k', '518k', '754k', '892k', '154k',
#        '860k', '364k', '387k', '626k', '161k', '879k', '39k', '970k',
#        '170k', '141k', '160k', '144k', '143k', '190k', '376k', '193k',
#        '246k', '73k', '658k', '992k', '253k', '420k', '404k', '1,000+',
#        '470k', '226k', '240k', '89k', '234k', '257k', '861k', '467k',
#        '157k', '44k', '676k', '67k', '552k', '885k', '1020k', '582k',
#        '619k'], dtype=object)

# %%
def func(x):
    if('M' in x):
        return float(x[:-1])*(1024);
    if('k' in x):
        return float(x[:-1])
df.Size.apply(func)
# Out:
# 0        19456.0
# 1        14336.0
# 2         8908.8
# 3        25600.0
# 4         2867.2
#           ...
# 10836    54272.0
# 10837     3686.4
# 10838     9728.0
# 10839        NaN
# 10840    19456.0
# Name: Size, Length: 10358, dtype: float64

# %%
df.Size = df["Size"].apply(func)

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating   Reviews     Size  Installs  Type Price Content Rating  \
# 0         4.1     159.0  19456.0       NaN  Free     0       Everyone
# 1         3.9     967.0  14336.0       NaN  Free     0       Everyone
# 2         4.7   87510.0   8908.8       NaN  Free     0       Everyone
# 3         4.5  215644.0  25600.0       NaN  Free     0           Teen
# 4         4.3     967.0   2867.2       NaN  Free     0       Everyone
# ...       ...       ...      ...       ...   ...   ...            ...
# 10836     4.5      38.0  54272.0       NaN  Free     0       Everyone
# 10837     5.0       4.0   3686.4       NaN  Free     0       Everyone
# 10838     NaN       3.0   9728.0       NaN  Free     0       Everyone
# 10839     4.5     114.0      NaN       NaN  Free     0     Mature 17+
# 10840     4.5  398307.0  19456.0       NaN  Free     0       Everyone
#
#                           Genres Last Updated         Current Ver  \
# 0                   Art & Design    07-Jan-18               1.0.0
# 1      Art & Design;Pretend Play    15-Jan-18               2.0.0
# 2                   Art & Design    01-Aug-18               1.2.4
# 3                   Art & Design    08-Jun-18  Varies with device
# 4        Art & Design;Creativity    20-Jun-18                 1.1
# ...                          ...          ...                 ...
# 10836                  Education    25-Jul-17                1.48
# 10837                  Education    06-Jul-18                   1
# 10838                    Medical    20-Jan-17                   1
# 10839          Books & Reference    19-Jan-15  Varies with device
# 10840                  Lifestyle    25-Jul-18  Varies with device
#
#               Android Ver
# 0            4.0.3 and up
# 1            4.0.3 and up
# 2            4.0.3 and up
# 3              4.2 and up
# 4              4.4 and up
# ...                   ...
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device
#
# [10358 rows x 13 columns]

# %%
df.Size.isna().sum()
# Out:
# 1527

# %%
df.Installs.isna().sum()
# Out:
# 0

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating   Reviews     Size     Installs  Type Price Content Rating  \
# 0         4.1     159.0  19456.0      10,000+  Free     0       Everyone
# 1         3.9     967.0  14336.0     500,000+  Free     0       Everyone
# 2         4.7   87510.0   8908.8   5,000,000+  Free     0       Everyone
# 3         4.5  215644.0  25600.0  50,000,000+  Free     0           Teen
# 4         4.3     967.0   2867.2     100,000+  Free     0       Everyone
# ...       ...       ...      ...          ...   ...   ...            ...
# 10836     4.5      38.0  54272.0       5,000+  Free     0       Everyone
# 10837     5.0       4.0   3686.4         100+  Free     0       Everyone
# 10838     NaN       3.0   9728.0       1,000+  Free     0       Everyone
# 10839     4.5     114.0      NaN       1,000+  Free     0     Mature 17+
# 10840     4.5  398307.0  19456.0  10,000,000+  Free     0       Everyone
#
#                           Genres Last Updated         Current Ver  \
# 0                   Art & Design    07-Jan-18               1.0.0
# 1      Art & Design;Pretend Play    15-Jan-18               2.0.0
# 2                   Art & Design    01-Aug-18               1.2.4
# 3                   Art & Design    08-Jun-18  Varies with device
# 4        Art & Design;Creativity    20-Jun-18                 1.1
# ...                          ...          ...                 ...
# 10836                  Education    25-Jul-17                1.48
# 10837                  Education    06-Jul-18                   1
# 10838                    Medical    20-Jan-17                   1
# 10839          Books & Reference    19-Jan-15  Varies with device
# 10840                  Lifestyle    25-Jul-18  Varies with device
#
#               Android Ver
# 0            4.0.3 and up
# 1            4.0.3 and up
# 2            4.0.3 and up
# 3              4.2 and up
# 4              4.4 and up
# ...                   ...
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device
#
# [10358 rows x 13 columns]

# %%
def checkInstalls(x):
    if '+' in x:
        return x[:-1]

# %%
df.Installs = df.Installs.apply(checkInstalls)

# %%
def removeCommas(x):
    if(x==None):
        return None
    return x.replace(',','')

# %%
df.Installs = df.Installs.apply(removeCommas)

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating   Reviews     Size  Installs  Type Price Content Rating  \
# 0         4.1     159.0  19456.0     10000  Free     0       Everyone
# 1         3.9     967.0  14336.0    500000  Free     0       Everyone
# 2         4.7   87510.0   8908.8   5000000  Free     0       Everyone
# 3         4.5  215644.0  25600.0  50000000  Free     0           Teen
# 4         4.3     967.0   2867.2    100000  Free     0       Everyone
# ...       ...       ...      ...       ...   ...   ...            ...
# 10836     4.5      38.0  54272.0      5000  Free     0       Everyone
# 10837     5.0       4.0   3686.4       100  Free     0       Everyone
# 10838     NaN       3.0   9728.0      1000  Free     0       Everyone
# 10839     4.5     114.0      NaN      1000  Free     0     Mature 17+
# 10840     4.5  398307.0  19456.0  10000000  Free     0       Everyone
#
#                           Genres Last Updated         Current Ver  \
# 0                   Art & Design    07-Jan-18               1.0.0
# 1      Art & Design;Pretend Play    15-Jan-18               2.0.0
# 2                   Art & Design    01-Aug-18               1.2.4
# 3                   Art & Design    08-Jun-18  Varies with device
# 4        Art & Design;Creativity    20-Jun-18                 1.1
# ...                          ...          ...                 ...
# 10836                  Education    25-Jul-17                1.48
# 10837                  Education    06-Jul-18                   1
# 10838                    Medical    20-Jan-17                   1
# 10839          Books & Reference    19-Jan-15  Varies with device
# 10840                  Lifestyle    25-Jul-18  Varies with device
#
#               Android Ver
# 0            4.0.3 and up
# 1            4.0.3 and up
# 2            4.0.3 and up
# 3              4.2 and up
# 4              4.4 and up
# ...                   ...
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device
#
# [10358 rows x 13 columns]

# %%
df.Installs.isna().sum()
# Out:
# 2

# %%
def changePrice(x):
    if(x=='0'):
        return float(0)
    if('$' in x):
        return float(x[1:])
    return

# %%
df.Price = df.Price.apply(changePrice)

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating   Reviews     Size  Installs  Type  Price Content Rating  \
# 0         4.1     159.0  19456.0     10000  Free    0.0       Everyone
# 1         3.9     967.0  14336.0    500000  Free    0.0       Everyone
# 2         4.7   87510.0   8908.8   5000000  Free    0.0       Everyone
# 3         4.5  215644.0  25600.0  50000000  Free    0.0           Teen
# 4         4.3     967.0   2867.2    100000  Free    0.0       Everyone
# ...       ...       ...      ...       ...   ...    ...            ...
# 10836     4.5      38.0  54272.0      5000  Free    0.0       Everyone
# 10837     5.0       4.0   3686.4       100  Free    0.0       Everyone
# 10838     NaN       3.0   9728.0      1000  Free    0.0       Everyone
# 10839     4.5     114.0      NaN      1000  Free    0.0     Mature 17+
# 10840     4.5  398307.0  19456.0  10000000  Free    0.0       Everyone
#
#                           Genres Last Updated         Current Ver  \
# 0                   Art & Design    07-Jan-18               1.0.0
# 1      Art & Design;Pretend Play    15-Jan-18               2.0.0
# 2                   Art & Design    01-Aug-18               1.2.4
# 3                   Art & Design    08-Jun-18  Varies with device
# 4        Art & Design;Creativity    20-Jun-18                 1.1
# ...                          ...          ...                 ...
# 10836                  Education    25-Jul-17                1.48
# 10837                  Education    06-Jul-18                   1
# 10838                    Medical    20-Jan-17                   1
# 10839          Books & Reference    19-Jan-15  Varies with device
# 10840                  Lifestyle    25-Jul-18  Varies with device
#
#               Android Ver
# 0            4.0.3 and up
# 1            4.0.3 and up
# 2            4.0.3 and up
# 3              4.2 and up
# 4              4.4 and up
# ...                   ...
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device
#
# [10358 rows x 13 columns]

# %%
df.Price.isna().sum()
# Out:
# 1

# %%
def clean(x):
    if(x=="Varies with device"):
        return np.nan
    if(type(x)==str):
        return x.replace(" and up","")

# %%
df["Android Ver"] = df["Android Ver"].apply(clean)

# %%
df.isna().sum()/df.shape[0]
# Out:
# App               0.000000
# Category          0.000000
# Rating            0.141437
# Reviews           0.000097
# Size              0.147422
# Installs          0.000193
# Type              0.000097
# Price             0.000097
# Content Rating    0.000097
# Genres            0.000000
# Last Updated      0.000000
# Current Ver       0.000772
# Android Ver       0.118170
# dtype: float64

# %%
df.drop(index=10472,inplace=True)

# %%
df["Android Ver"].fillna(df["Android Ver"].mode()[0],inplace=True)

# %%
df.Rating.fillna(df.Rating.mean(),inplace = True)

# %%
df.Size.fillna(df.Size.median(),inplace = True)

# %%
df.dropna(inplace = True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.distplot(df["Rating"])
# Out:
# c:\Users\deepr\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %%
sns.distplot(df["Installs"])
# Out:
# c:\Users\deepr\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Installs', ylabel='Density'>

# %%
sns.distplot(df["Size"])
# Out:
# c:\Users\deepr\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Size', ylabel='Density'>
